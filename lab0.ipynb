# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
import seaborn as sns
# %matplotlib inline

# %%
# Create a dataframe with columns named 'x' and 'y' filled with random numbers
df = pd.DataFrame({"x": np.random.normal(size=50), "y": np.random.normal(size=50)})

# Create an ordinary least squares regression on the data and show summary statistics.
# This formula regresses column 'y' on 'x'
ro = sm.OLS.from_formula("y ~ x", df)
res = ro.fit()
print(res.summary())

# Plot the data
sns.regplot('x', 'y', df)
plt.show()
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.021
# Method:                 Least Squares   F-statistic:                 0.0004127
# Date:                Wed, 26 Jan 2022   Prob (F-statistic):              0.984
# Time:                        19:59:20   Log-Likelihood:                -68.275
# No. Observations:                  50   AIC:                             140.6
# Df Residuals:                      48   BIC:                             144.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.1589      0.137     -1.160      0.252      -0.434       0.117
# ...

# %%
DATA_ROOT = '/Users/aidenbingham/ALL CSV FILES - 2nd Edition/'
data = pd.read_csv(DATA_ROOT+'Advertising.csv')
data.info()
data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   TV          200 non-null    float64
#  2   radio       200 non-null    float64
#  3   newspaper   200 non-null    float64
#  4   sales       200 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 7.9 KB
#        Unnamed: 0          TV       radio   newspaper       sales
# count  200.000000  200.000000  200.000000  200.000000  200.000000
# mean   100.500000  147.042500   23.264000   30.554000   14.022500
# std     57.879185   85.854236   14.846809   21.778621    5.217457
# min      1.000000    0.700000    0.000000    0.300000    1.600000
# 25%     50.750000   74.375000    9.975000   12.750000   10.375000
# 50%    100.500000  149.750000   22.900000   25.750000   12.900000
# ...

# %%
data.plot(x='TV', y='sales', style='o')
plt.title('TV vs sales')
plt.xlabel('TV')
plt.ylabel('sales')
plt.show()

# %%
df = pd.DataFrame({"TV": data.TV, "sales": data.sales})

ro = sm.OLS.from_formula("TV ~ sales", df)
res = ro.fit()
print(res.summary())

# Plot the data
sns.regplot('TV', 'sales', df)
plt.show()
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                     TV   R-squared:                       0.612
# Model:                            OLS   Adj. R-squared:                  0.610
# Method:                 Least Squares   F-statistic:                     312.1
# Date:                Wed, 26 Jan 2022   Prob (F-statistic):           1.47e-42
# Time:                        19:59:21   Log-Likelihood:                -1079.2
# No. Observations:                 200   AIC:                             2162.
# Df Residuals:                     198   BIC:                             2169.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    -33.4502     10.897     -3.070      0.002     -54.939     -11.961
# ...

# %%
data.plot(x='radio', y='sales', style='o')
plt.title('radio vs sales')
plt.xlabel('radio')
plt.ylabel('sales')
plt.show()

# %%
df = pd.DataFrame({"radio": data.radio, "sales": data.sales})

ro = sm.OLS.from_formula("radio ~ sales", df)
res = ro.fit()
print(res.summary())

# Plot the data
sns.regplot('radio', 'sales', df)
plt.show()
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  radio   R-squared:                       0.332
# Model:                            OLS   Adj. R-squared:                  0.329
# Method:                 Least Squares   F-statistic:                     98.42
# Date:                Wed, 26 Jan 2022   Prob (F-statistic):           4.35e-19
# Time:                        19:59:23   Log-Likelihood:                -782.49
# No. Observations:                 200   AIC:                             1569.
# Df Residuals:                     198   BIC:                             1576.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.2713      2.472      0.110      0.913      -4.604       5.146
# ...

# %%
data.plot(x='newspaper', y='sales', style='o')
plt.title('newspaper vs sales')
plt.xlabel('newspaper')
plt.ylabel('sales')
plt.show()

# %%
df = pd.DataFrame({"newspaper": data.newspaper, "sales": data.sales})

ro = sm.OLS.from_formula("newspaper ~ sales", df)
res = ro.fit()
print(res.summary())

# Plot the data
sns.regplot('newspaper', 'sales', df)
plt.show()
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              newspaper   R-squared:                       0.052
# Model:                            OLS   Adj. R-squared:                  0.047
# Method:                 Least Squares   F-statistic:                     10.89
# Date:                Wed, 26 Jan 2022   Prob (F-statistic):            0.00115
# Time:                        19:59:23   Log-Likelihood:                -894.12
# No. Observations:                 200   AIC:                             1792.
# Df Residuals:                     198   BIC:                             1799.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     17.1911      4.320      3.980      0.000       8.672      25.710
# ...
